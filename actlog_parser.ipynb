# %%
from actlogs_console import ActLogs

# %%
al = ActLogs(path="./data/hdl_test.log")
al.focus(focus_action_ids=['15', '1A', '1E', '1F'], focus_action_names=['弗萝北'])
print(len(al))
lines = [al[idx] for idx in range(len(al))]
pdd = pd.DataFrame(lines)
# Out:
# 851

# %%
columns = [
    'time', 'skill_id', 'skill_name', 'action_id', 
    'feat_a', 'feat_b', 'feat_c', 'feat_d', 
    'active', 'summon', 'summon_stack', 'next_attach', 'aetherflow']
pdd[:60][columns].where(pdd[:60][columns].notnull(), "")
# Out:
#             time skill_id skill_name action_id    feat_a    feat_b    feat_c  \
# 0   23:45:35.087      DFB         毁荡        15
# 1   23:45:36.024     64C9       灼热之光        15
# 2   23:45:37.628      DFB         毁荡        15
# 3   23:45:38.252      130       以太超流        1A
# 4   23:45:38.252     407C       能量吸收        15
# 5   23:45:38.252      A8D       毁绝预备        1A
# 6   23:45:38.252                            1F  0000001B  00000000  10195F02
# 7   23:45:40.035      DFB         毁荡        15
# 8   23:45:41.551     1D03       龙神召唤        15
# 9   23:45:41.551                            1F  003A981B  00001700  E00000E2
# 10  23:45:44.009     64DC       星极脉冲        15
# 11  23:45:44.635      130       以太超流        1A
# 12  23:45:44.635       B5       溃烂爆发        15
# 13  23:45:44.635                            1F  002E8C1B  00001700  000000E1
# 14  23:45:45.259       30         进食        1A
# 15  23:45:45.259     1D05       龙神迸发        15
# 16  23:45:46.418     64DC       星极脉冲        15
# 17  23:45:47.043       B5       溃烂爆发        15
# 18  23:45:47.043      130       以太超流        1E
# 19  23:45:47.043                            1F  0025251B  00001700  10195FE0
# 20  23:45:48.870     64DC       星极脉冲        15
# 21  23:45:49.494      DFE       死星核爆        15
# 22  23:45:51.325     64DC       星极脉冲        15
# 23  23:45:51.949     1D8A         醒梦        15
# 24  23:45:52.573      4B4         醒梦        1A
# 25  23:45:53.778     64DC       星极脉冲        15
# 26  23:45:56.184     64DC       星极脉冲        15
# 27  23:45:56.585                            1F  0000001B  00000000  E00000F0
# 28  23:45:58.631     64CD       火神召唤        15
# 29  23:45:58.631      AA4     深红旋风预备        1A
# 30  23:45:58.631                            1F  301F401B  02001775  10195FD4
# 31  23:45:59.121      B3C     守护者的职责        1A
# 32  23:46:02.813                            1F  DA00001B  02000064  1019E3D4
# 33  23:46:03.258     64DF      红宝石之仪        15
# 34  23:46:03.258                            1F  1E00001B  01000063  000000D4
# 35  23:46:06.106     64DF      红宝石之仪        15
# 36  23:46:06.106                            1F  0000001B  00000000  1019C3D0
# 37  23:46:07.486      B3C     守护者的职责        1E
# 38  23:46:07.486      B3E     演艺家的职责        1A
# 39  23:46:07.620     64EB       深红旋风        15
# 40  23:46:07.620      AA4     深红旋风预备        1E
# 41  23:46:10.022     651D       深红强袭        15
# 42  23:46:12.474     64CE       土神召唤        15
# 43  23:46:12.474                            1F  301F401B  04001775  E0000098
# 44  23:46:13.540      4B4         醒梦        1E
# 45  23:46:14.966     64E0      黄宝石之仪        15
# 46  23:46:14.966      B25       山崩预备        1A
# 47  23:46:14.966                            1F  7515851B  0300176B  10195F98
# 48  23:46:15.589     64EC         山崩        15
# 49  23:46:15.589      B25       山崩预备        1E
# 50  23:46:16.657                            1F  D900001B  03000064  E0000098
# 51  23:46:17.369     64E0      黄宝石之仪        15
# 52  23:46:17.369      B25       山崩预备        1A
# 53  23:46:17.369                            1F  1200001B  02000062  10195F98
# 54  23:46:18.038     64EC         山崩        15
# 55  23:46:18.038      B25       山崩预备        1E
# 56  23:46:19.777     64E0      黄宝石之仪        15
# 57  23:46:19.777      B25       山崩预备        1A
# 58  23:46:19.777                            1F  A900001B  01000058  00000098
# 59  23:46:20.402     64EC         山崩        15
#
#       feat_d active                  summon summon_stack next_attach  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6   00000000   None                  [, , ]          0.0     Bahamut
# 7
# 8
# 9   000004D3   None  [Ruby, Topaz, Emerald]          0.0     Bahamut
# 10
# 11
# 12
# 13  00000000   None  [Ruby, Topaz, Emerald]          0.0     Bahamut
# 14
# 15
# 16
# 17
# 18
# 19  00000000   None  [Ruby, Topaz, Emerald]          0.0     Bahamut
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27  00000AA0   None  [Ruby, Topaz, Emerald]          0.0     Phoenix
# 28
# 29
# 30  00000B1C   None      [, Topaz, Emerald]          2.0     Phoenix
# 31
# 32  00000511   None      [, Topaz, Emerald]          2.0     Phoenix
# 33
# 34  00000000   None      [, Topaz, Emerald]          1.0     Phoenix
# 35
# 36  000008A9   None      [, Topaz, Emerald]          0.0     Phoenix
# 37
# 38
# 39
# 40
# 41
# 42
# 43  000004D7   None           [, , Emerald]          4.0     Phoenix
# 44
# 45
# 46
# 47  00000B1C   None           [, , Emerald]          3.0     Phoenix
# 48
# 49
# 50  00000000   None           [, , Emerald]          3.0     Phoenix
# 51
# 52
# 53  00000B1C   None           [, , Emerald]          2.0     Phoenix
# 54
# 55
# 56
# 57
# 58  00000000   None           [, , Emerald]          1.0     Phoenix
# 59
#
#    aetherflow
# 0
# 1
# 2
# 3
# 4
# 5
# 6         2.0
# 7
# 8
# 9         2.0
# 10
# 11
# 12
# 13        1.0
# 14
# 15
# 16
# 17
# 18
# 19        0.0
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27        0.0
# 28
# 29
# 30        0.0
# 31
# 32        0.0
# 33
# 34        0.0
# 35
# 36        0.0
# 37
# 38
# 39
# 40
# 41
# 42
# 43        0.0
# 44
# 45
# 46
# 47        0.0
# 48
# 49
# 50        0.0
# 51
# 52
# 53        0.0
# 54
# 55
# 56
# 57
# 58        0.0
# 59

# %%
lines[0]
# Out:
# [{'time': '23:45:35.087',
#   'action_id': '15',
#   'action_type': 'ActionEffect',
#   'source_id': '10195F52',
#   'source_name': '弗萝北',
#   'action_code': 'DFB',
#   'action_name': '毁荡',
#   'target_id': '4000B887',
#   'target_name': '海德林',
#   'target_hp': '13065478',
#   'target_maxhp': '13065478',
#   'target_mp': '10000',
#   'target_maxmp': '10000',
#   'target_position': ['99.99', '90.00', '0.00', '0.00'],
#   'source_hp': '40917',
#   'source_maxhp': '40917',
#   'source_mp': '10000',
#   'source_maxmp': '10000',
#   'source_position': ['99.47', '113.76', '0.00', '3.12']}]

# %%
# Out:
# 0
